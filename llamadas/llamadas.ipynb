# %%
import pandas as pd
from datetime import datetime
import locale

# %% [markdown]
# ## Trabajo sobre el archivo descargado

# %% [markdown]
# Descargo el archivo de TecnoVoz. Ya en la carpeta cambio el nombre en el paso 1 y dejo que corra el resto del código.

# %% [markdown]
# *En Excel abrir el csv, ir a datos, importar datos desde CSV y guardar como Excel. Chequear que no haya columnas vacías y personas que no son operadores. Borrar el "ARCHIVO... COMAS"

# %% [markdown]
# #### Trabajo sobre el archivo, columnas, operadores

# %%
#Con pandas traigo los datos del archivo de llamadas por operador

datos = pd.read_csv("./mensual.csv", delimiter=";")
datos.columns
# Out:
# Index(['USERID', 'AGENTID', 'CSESSION', 'PCTDELAY', 'CTALKING_I', 'CTALKING_O',
#        'CTALKING', 'PCTTALKING', 'CACW', 'PCTACW', 'CALLS_I', 'CALLS_O',
#        'CALLS', 'CONEXAVG_I', 'CONEXAVG_O', 'CONEXAVG', 'CWAITING',
#        'PCTWAITING', 'PCTABC', 'CDND', 'PCTDND', 'CDELAY', 'XFER', 'XFERED',
#        'THRCOUNT', 'CTHRTALKING', 'CHOLD', 'CCNSTIME', 'CNSNUM', 'CCNSEDTIME',
#        'CNSEDNUM', 'CCNSNOHTIME', 'CNSNOHNUM', 'ALOGIN', 'TOTLOGIN',
#        'NOANSWER', 'Unnamed: 36'],
#       dtype='object')

# %%
#Borro las columnas innecesarias

columnas_borrar = ['USERID', 'CSESSION', 'PCTDELAY', 'CTALKING_I', 'CTALKING_O', 'CTALKING', 'CACW', 'PCTACW', 'CONEXAVG_I', 'CONEXAVG_O', 'CONEXAVG', 'CWAITING', 'PCTWAITING', 
       'CDELAY', 'XFER', 'XFERED', 'THRCOUNT', 'CTHRTALKING', 'CHOLD', 'CCNSTIME', 'CNSNUM', 'CCNSEDTIME', 'CNSEDNUM', 'CCNSNOHTIME', 'CNSNOHNUM', 'ALOGIN', 'TOTLOGIN', 'Unnamed: 36']
datos = datos.drop(columnas_borrar, axis = 1)
datos.columns
# Out:
# Index(['AGENTID', 'PCTTALKING', 'CALLS_I', 'CALLS_O', 'CALLS', 'PCTABC',
#        'CDND', 'PCTDND', 'NOANSWER'],
#       dtype='object')

# %%
#Cambio el nombre de las columnas por las que voy a usar
nuevos_nombres = ["Operador", "Porc. en llamadas", "Entrantes", "Manuales", "Salientes", "Porc. disp", "No disp (HR)", "Porc. no disp", "No respondidas"]
datos.columns = nuevos_nombres

# %%
#Borro aquellos que no son operadores

valores_a_excluir = ["VGARRAMONE", "VRUIZ", "MSERKIN", "MAVOLIO", "MLOTZ", "IVILLAGRA", "JRIVERA", "BPEREZ", "RFONTAN", "GDESANTANA", "KMENDES", "MGATTI", "TST", "MSCARSO",
                    "MVAGENT", "ADECASTRO", "ECALLEJAS"]
datos = datos.loc[~datos['Operador'].isin(valores_a_excluir)]
datos = datos.reset_index(drop=True)

# %%
#Creo un mapeo de nombre: "NOMBRE CON EL QUE APARECE AL DESCARGARSE" : "NOMBRE A COLOCAR"

    "TMEDEIROS":"MEDEIROS CASTELO THAYNARA LORRANA",
    "NSTARK":"NESTOR DANIEL STARK",
    "AONORATI":"ONORATI BELLI AGOSTINA AILEN",
    "EOROPEZA":"OROPEZA RODRIGUEZ ESTHEFANIA IVELISSA",
    "MPARLAG":"PARLAGRECO MATIAS",
    "MPISANI":"PISANI MARIANO NICOLAS",
    "EPORTO":"PORTO MACHADO ELICA",
    "DQUIROGA":"QUIROGA DANIELA MARIBEL",
    "ARAMOS":"RAMOS DOS SANTOS AKLA KEZIA",
    "PRENGEL":"RENGEL PEDRO FELIPE",
    "FRODRIGUES":"RODRIGUES FELIP",
    "MROMERSTEI":"ROMERSTEIN MARIA FLORENCIA",
    "GROSILLO":"ROSILLO HERRERA GUSTAVO",
    "NRUIZ":"RUIZ NATALIA",
    "RSANTOS":"SANTOS DE JESUS ROQUELINA",
    "GSEMONI":"SEMONI GUIDO",
    "RSILVA":"SILVA DE ATAIDE ROBERTO",
    "STEIXEIRA":"SOFIA TEIXEIRA PORTELLA",
    "SSOUSA":"SOUSA DA COSTA SABRINA",
    "ALUIZ":"TOSTA ANDRYEL LUIZ",
    "RURIBE":"URIBE REBECCA",
    "LVIVAS":"VIVAS NIETO LEGNA GRISEL"
}

# %%
#Cambio los nombres con los que estaban registrados los operadores por su nombre completo

datos['Operador'] = datos['Operador'].map(mapeo_nombres)

# %%
#Paso los porcentajes a strings para que se pasen correctamente cuando los exporto y poder trabajar con ellos

datos["Porc. en llamadas"] = datos["Porc. en llamadas"].astype(str)
datos["Porc. no disp"] = datos["Porc. no disp"].astype(str)
datos["Porc. disp"] = datos["Porc. disp"].astype(str)

# %%
#Reemplazo los puntos por coma asi en Excel puedo operar correctamente

datos["Porc. en llamadas"] = datos["Porc. en llamadas"].str.replace('.', ',')
datos["Porc. no disp"] = datos["Porc. no disp"].str.replace('.', ',')
datos["Porc. disp"] = datos["Porc. disp"].str.replace('.', ',')

# %%
#Creo el conjunto de operadores por Expertice
supervisores = ["DOS SANTOS DOMINGUES CAMILA CAROLINA", "GONZALEZ FERNANDO EZEQUIEL", "NESTOR DANIEL STARK", "OROPEZA RODRIGUEZ ESTHEFANIA IVELISSA", "RENGEL PEDRO FELIPE"]
team_leader = ["LARRIEL GAYOSO LAURA SOLEDAD", "MARTINO IVAN EZEQUIEL", "MARTINO NICOLAS EZEQUIEL", "MATHEUS SABINO FARIA"]
senior = ["COSTA SANTOS SILVA LORRANA", "DUEÑAS RODRIGUEZ ALEXANDER WASHINGTON", "GANDARA MAXIMO", "GARAVENTA ANIBAL DANIEL", "GODOY CARVAJAL ANNA PAOLA", "GONGO RENATO CANDIDO GONCALVES",
          "GONZALEZ MARTIN ESTEBAN", "LOBO SAENZ ELIANGEL", "MARTINEZ LEANDRO GABRIEL", "MARTINEZ RAMIREZ SINAI DANIELA", "PARLAGRECO MATIAS", "PISANI MARIANO NICOLAS", 
          "QUIROGA DANIELA MARIBEL"]

# Definir la función para asignar el valor de "expertice" en función de "Operador"
def asignar_expertice(row):
    operador = row['Operador']
    if operador in team_leader:
        return 'Team Leader'
    elif operador in senior:
        return 'Senior'
    elif operador in supervisores:
        return 'Sup'
    else:
        return 'Junior'

# Aplico la función a la columna Expertice
datos['Expertice'] = datos.apply(asignar_expertice, axis=1)

# %%
#Creo el conjunto de operadores por Turno
maniana = ["CHARRIER LUIZ RAFAEL", "COSTA SANTOS SILVA LORRANA", "DA COSTA PEREIRA MAYARA", "DA FONSECA MIGUEL", "DA MATA ARGUELHO GUILHERME HENRIQUE", "DOS SANTOS DOMINGUES CAMILA CAROLINA",
           "DUEÑAS RODRIGUEZ ALEXANDER WASHINGTON", "ESTIVILL SOSENKO ISMAEL", "FERNANDES TOME LUANA VANESSA", "GANDARA FRANCO", "GODOY CARVAJAL ANNA PAOLA", "HOBERT DELFINA",
           "MARTINEZ RAMIREZ SINAI DANIELA", "MARTINO IVAN EZEQUIEL", "MARTINS DA SILVA MARIA EDUARDA", "ONORATI BELLI AGOSTINA AILEN", "PISANI MARIANO NICOLAS", "PORTO MACHADO ELICA", 
           "SOFIA TEIXEIRA PORTELLA"]
noche = ["DA SILVA ALISSON LUCAS ALVES", "DA SILVA SOUZA THASSIA STEPHANIE", "DOS SANTOS DENER", "IBARRA GARCIA CARLOS ANDRES", "ROSILLO HERRERA GUSTAVO", "TOSTA ANDRYEL LUIZ", 
         "URIBE REBECCA"]
dia_sdf = ["CORDEIRO TRINDADE IUCARA", "CUNHA DE ALMEIDA FRANCISCA ELISANGELA", "DA SILVA SANTOS EMILY DAYANE", "FERREIRA DE SANTANA CARVALHO GABRIELLE", "FLANAGAN PAOLA ANDREA",
           "GAMEZ FERNANDEZ ANGEL GABRIEL", "GARAVENTA ANIBAL DANIEL", "GONCALVES LIMA ADELINA KATIA", "LOBO SAENZ ELIANGEL", "LOPEZ MICAELA SOLEDAD", "MARQUES PEREIRA DARA", 
           "MATHEUS SABINO FARIA", "QUIROGA DANIELA MARIBEL", "SEMONI GUIDO"]
noche_sdf = ["GIL SOTO KEVIN ADRIAN", "RAMOS DOS SANTOS AKLA KEZIA", "ROMERSTEIN MARIA FLORENCIA", "RUIZ NATALIA", "SANTOS DE JESUS ROQUELINA", "SILVA DE ATAIDE ROBERTO"]

# Definir la función para asignar el valor de "Turno" en función de "Operador"
def asignar_turno(row):
    operador = row['Operador']
    if operador in maniana:
        return 'Mañana'
    elif operador in noche:
        return 'Noche'
    elif operador in dia_sdf:
        return 'Dia (SDF)'
    elif operador in noche_sdf:
        return 'Noche (SDF)'
    else:
        return 'Tarde'

#Aplico la función a la columna Turno
datos['Turno'] = datos.apply(asignar_turno, axis=1)

# %%
#Creo el conjunto de operadores por Equipo
riesgo_propio = ["FERNANDES TOME LUANA VANESSA", "FLANAGAN PAOLA ANDREA", "GARAVENTA ANIBAL DANIEL", "GODOY CARVAJAL ANNA PAOLA"]
riesgo_tpa = ["DUEÑAS RODRIGUEZ ALEXANDER WASHINGTON", "FERREIRA ADRIEL", "GAMEZ FERNANDEZ ANGEL GABRIEL", "GANDARA FRANCO", "GONZALEZ MARTIN ESTEBAN", "GUERRERO CHACON MAYLU DANIELA"
              "IBARRA GARCIA CARLOS ANDRES", "LARRIEL GAYOSO LAURA SOLEDAD", "MARTINEZ BRACHO ANGEL GABRIEL", "MARTINEZ LEANDRO GABRIEL", "PISANI MARIANO NICOLAS", "GIL SOTO KEVIN ADRIAN"]
riesgo_tpa_br = ["PORTO MACHADO ELICA"]
riesgo_tpa_inter = ["GANDARA MAXIMO", "LOBO SAENZ ELIANGEL", "LOPEZ MICAELA SOLEDAD", "MARTINEZ RAMIREZ SINAI DANIELA", "QUIROGA DANIELA MARIBEL", "ROMERSTEIN MARIA FLORENCIA",
                    "SEMONI GUIDO", "URIBE REBECCA"]
tpa = ["ESTIVILL SOSENKO ISMAEL", "FONTAN JUAN PABLO ESTEBAN", "HOBERT DELFINA", "PARLAGRECO MATIAS", "ROSILLO HERRERA GUSTAVO", "RUIZ NATALIA"]
tpa_inter = ["ONORATI BELLI AGOSTINA AILEN"]

# Definir la función para asignar el valor de "Equipo" en función de "Operador"
def asignar_equipo(row):
    operador = row['Operador']
    if operador in riesgo_propio:
        return 'Riesgo propio'
    elif operador in riesgo_tpa:
        return 'Riesgo-TPA'
    elif operador in riesgo_tpa_br:
        return 'Riesgo-TPA-BR'
    elif operador in riesgo_tpa_inter:
        return 'Riesgo-TPA-Inter'
    elif operador in tpa:
        return 'TPA'
    elif operador in tpa_inter:
        return 'TPA-Inter'
    else:
        return 'Riesgo propio-BR'

#Aplico la función a la columna Turno
datos['Equipo'] = datos.apply(asignar_equipo, axis=1)

# %%
# Definir las columnas en el orden deseado
columnas_deseadas = ['Operador', 'Expertice', 'Turno', 'Equipo','Porc. en llamadas', 'Entrantes', 'Manuales', 'Salientes', 'Porc. disp', 'No disp (HR)', 'Porc. no disp', 'No respondidas']

# Reordenar las columnas del DataFrame
datos = datos.reindex(columns=columnas_deseadas)

# %%
#Esta es la tabla final
datos
# Out:
#                                 Operador Expertice      Turno
# 0                      PARLAGRECO MATIAS    Senior      Tarde  \
# 1               MARTINEZ LEANDRO GABRIEL    Senior      Tarde
# 2                        FERREIRA ADRIEL    Junior      Tarde
# 3          GAMEZ FERNANDEZ ANGEL GABRIEL    Junior  Dia (SDF)
# 4                 PISANI MARIANO NICOLAS    Senior     Mañana
# ..                                   ...       ...        ...
# 68         MARTINEZ BRACHO ANGEL GABRIEL    Junior      Tarde
# 69                                   NaN    Junior      Tarde
# 70                                   NaN    Junior      Tarde
# 71  DOS SANTOS DOMINGUES CAMILA CAROLINA       Sup     Mañana
# 72                                   NaN    Junior      Tarde
#
#               Equipo Porc. en llamadas  Entrantes  Manuales  Salientes
# 0                TPA             14,29        142       274        416  \
# 1         Riesgo-TPA              10,3         35       378        413
# 2         Riesgo-TPA              13,0         85       309        394
# 3         Riesgo-TPA             10,98         69       263        332
# 4         Riesgo-TPA             11,35        133       189        322
# ..               ...               ...        ...       ...        ...
# 68        Riesgo-TPA              1,01          0         6          6
# 69  Riesgo propio-BR             23,17          5         0          5
# 70  Riesgo propio-BR              4,78          0         4          4
# 71  Riesgo propio-BR              1,76          0         4          4
# 72  Riesgo propio-BR              1,89          0         0          0
#
#    Porc. disp No disp (HR) Porc. no disp  No respondidas
# 0       70,18     54:35:23         29,82               6
# 1       36,56    112:52:01         63,44               1
# 2       94,38     07:54:02          5,62               0
# 3       62,26     63:18:19         37,74               3
# 4       76,26     36:55:11         23,74               5
# ..        ...          ...           ...             ...
# 68       1,37     27:27:54         98,63               0
# 69      96,05     00:04:58          3,95               0
# 70      76,74     00:02:16         23,26               0
# 71       1,93     31:51:26         98,07               0
# 72       4,59     09:44:27         95,41               1
#
# [73 rows x 12 columns]

# %% [markdown]
# #### Trabajo sobre el nombre del archivo a descargar

# %%
# Establecer la configuración regional en español para que el mes se registre en español
locale.setlocale(locale.LC_TIME, 'es_ES.UTF-8')

# Obtener la fecha actual
fecha_actual = datetime.now()

# Obtener el número del mes actual
numero_mes_actual = fecha_actual.strftime("%m")

# Obtener el nombre del mes actual
nombre_mes_actual = fecha_actual.strftime("%B").capitalize()

# Obtener el año actual
anio_actual = fecha_actual.year

# Obtener el día del mes actual
dia_actual = fecha_actual.day

# Determinar el tipo de quincena
if dia_actual >= 1 and dia_actual <= 15:
    tipo_quincena = "2da quincena"
else:
    tipo_quincena = "1ra quincena"

# Generar el nombre del archivo con el formato deseado
nombre_archivo = f"{numero_mes_actual}. {nombre_mes_actual} {anio_actual} - {tipo_quincena}.csv"

# %%
#Chequeo que sea el numero de mes correcto
print("Numero de mes: ", numero_mes_actual)
#Chequeo que sea el mes correcto
print("Mes: ", nombre_mes_actual)
#Chequeo que sea el año actual
print("Año: ", anio_actual)
#Chequeo que sea la quincena correcta
print(tipo_quincena)
#Veo el nombre del archivo
print(nombre_archivo)
# Out:
# Numero de mes:  06
# Mes:  Junio
# Año:  2023
# 2da quincena
# 06. Junio 2023 - 2da quincena.csv

# %%
#Creo el excel para turno SDF

datos2 = datos[datos["Turno"].isin(["Dia (SDF)", "Noche (SDF)"]) & ~datos['Expertice'].isin(["Sup"])]
nombre_sdf = f"{nombre_mes_actual} SDF.csv"
datos2
# Out:
#                                   Operador    Expertice        Turno
# 3            GAMEZ FERNANDEZ ANGEL GABRIEL       Junior    Dia (SDF)  \
# 6                             SEMONI GUIDO       Junior    Dia (SDF)
# 16                   LOPEZ MICAELA SOLEDAD       Junior    Dia (SDF)
# 21                            RUIZ NATALIA       Junior  Noche (SDF)
# 24                 QUIROGA DANIELA MARIBEL       Senior    Dia (SDF)
# 31                CORDEIRO TRINDADE IUCARA       Junior    Dia (SDF)
# 38                   GIL SOTO KEVIN ADRIAN       Junior  Noche (SDF)
# 40                    MARQUES PEREIRA DARA       Junior    Dia (SDF)
# 44                     LOBO SAENZ ELIANGEL       Senior    Dia (SDF)
# 46                 GARAVENTA ANIBAL DANIEL       Senior    Dia (SDF)
# 47  FERREIRA DE SANTANA CARVALHO GABRIELLE       Junior    Dia (SDF)
# 51                 SILVA DE ATAIDE ROBERTO       Junior  Noche (SDF)
# 52            DA SILVA SANTOS EMILY DAYANE       Junior    Dia (SDF)
# 54            GONCALVES LIMA ADELINA KATIA       Junior    Dia (SDF)
# 55   CUNHA DE ALMEIDA FRANCISCA ELISANGELA       Junior    Dia (SDF)
# 56               SANTOS DE JESUS ROQUELINA       Junior  Noche (SDF)
# 57                    MATHEUS SABINO FARIA  Team Leader    Dia (SDF)
# 58             RAMOS DOS SANTOS AKLA KEZIA       Junior  Noche (SDF)
# 66              ROMERSTEIN MARIA FLORENCIA       Junior  Noche (SDF)
# 67                   FLANAGAN PAOLA ANDREA       Junior    Dia (SDF)
#
#               Equipo Porc. en llamadas  Entrantes  Manuales  Salientes
# 3         Riesgo-TPA             10,98         69       263        332  \
# 6   Riesgo-TPA-Inter              9,02         49       247        296
# 16  Riesgo-TPA-Inter              7,76         36       167        203
# 21               TPA              5,72         48       118        166
# 24  Riesgo-TPA-Inter              5,49         48       106        154
# 31  Riesgo propio-BR               4,0         39        54         93
# 38        Riesgo-TPA               2,9         18        46         64
# 40  Riesgo propio-BR              2,82         33        31         64
# 44  Riesgo-TPA-Inter              6,18          7        45         52
# 46     Riesgo propio              1,29         37        13         50
# 47  Riesgo propio-BR               4,4         22        27         49
# 51  Riesgo propio-BR              2,04          7        37         44
# 52  Riesgo propio-BR              1,67         24        17         41
# 54  Riesgo propio-BR              1,38         32         4         36
# 55  Riesgo propio-BR              1,37         30         6         36
# 56  Riesgo propio-BR              1,48         27         6         33
# 57  Riesgo propio-BR              1,18          8        21         29
# 58  Riesgo propio-BR              1,42         14        13         27
# 66  Riesgo-TPA-Inter              1,66          9         3         12
# 67     Riesgo propio              1,09          7         5         12
#
#    Porc. disp No disp (HR) Porc. no disp  No respondidas
# 3       62,26     63:18:19         37,74               3
# 6       43,34     96:32:58         56,66               1
# 16      63,79     56:02:24         36,21               1
# 21      95,34     07:23:22          4,66               6
# 24       54,1     59:57:26          45,9               4
# 31      85,14     18:55:02         14,86               1
# 38      61,68     40:30:15         38,32               1
# 40      69,98     41:50:28         30,02               2
# 44      69,85     13:06:04         30,15               1
# 46      51,76     42:41:36         48,24              11
# 47      82,44     06:32:06         17,56               0
# 51      60,98     47:20:20         39,02               2
# 52      75,55     30:32:41         24,45               4
# 54      86,71     16:34:38         13,29               0
# 55      88,55     13:55:47         11,45               5
# 56      92,82     10:02:23          7,18              12
# 57      48,98     55:30:30         51,02               6
# 58      94,61     07:24:26          5,39               2
# 66      93,52     02:11:26          6,48               1
# 67      51,32     23:05:38         48,68               2

# %%
#Creo el excel para turno mañana, tarde, noche

# 68          MARTINEZ BRACHO ANGEL GABRIEL       Junior   Tarde
# 69                                    NaN       Junior   Tarde
# 70                                    NaN       Junior   Tarde
# 72                                    NaN       Junior   Tarde
#
#               Equipo Porc. en llamadas  Entrantes  Manuales  Salientes
# 0                TPA             14,29        142       274        416  \
# 1         Riesgo-TPA              10,3         35       378        413
# 2         Riesgo-TPA              13,0         85       309        394
# 4         Riesgo-TPA             11,35        133       189        322
# 5   Riesgo-TPA-Inter             14,45        141       177        318
# 7                TPA             11,12        116       180        296
# 8                TPA               6,4          1       238        239
# 9   Riesgo propio-BR              11,6         10       226        236
# 10        Riesgo-TPA              7,01         80       155        235
# 11               TPA              9,31         48       185        233
# 12         TPA-Inter              8,02         30       194        224
# 13  Riesgo propio-BR              6,29         86       130        216
# 14  Riesgo-TPA-Inter              5,25         65       149        214
# 15        Riesgo-TPA              6,64         62       144        206
# 17  Riesgo propio-BR              7,34         27       173        200
# 18  Riesgo propio-BR              5,88         50       140        190
# 19        Riesgo-TPA              5,24         65       117        182
# 20  Riesgo propio-BR              6,79         45       125        170
# 22  Riesgo propio-BR              4,75        113        46        159
# 23  Riesgo propio-BR              4,76         73        83        156
# 25  Riesgo propio-BR               3,2        113        35        148
# 26  Riesgo propio-BR              5,55         16       128        144
# 27     Riesgo-TPA-BR              2,55         97        41        138
# 28     Riesgo propio              5,71         96        27        123
# 29  Riesgo propio-BR              3,92         80        41        121
# 30     Riesgo propio              3,94         92        20        112
# 32  Riesgo propio-BR              5,31         41        48         89
# 33  Riesgo propio-BR              1,66         52        35         87
# 34  Riesgo propio-BR              2,71         48        37         85
# 35  Riesgo propio-BR              2,56         64        18         82
# 36  Riesgo propio-BR              3,52          9        64         73
# 37        Riesgo-TPA              1,76         23        49         72
# 39  Riesgo propio-BR               2,7         51        13         64
# 41  Riesgo propio-BR              1,98         44        17         61
# 42  Riesgo-TPA-Inter              2,95         32        26         58
# 43               TPA              2,54          8        46         54
# 45  Riesgo propio-BR              1,77         31        19         50
# 48  Riesgo propio-BR              1,48         33        16         49
# 49  Riesgo propio-BR              3,63          6        40         46
# 53  Riesgo propio-BR              1,01         17        23         40
# 61  Riesgo propio-BR              0,71          9        10         19
# 63  Riesgo propio-BR              1,47         16         1         17
# 64  Riesgo propio-BR              6,45          0        16         16
# 65  Riesgo propio-BR              2,72         13         0         13
# 68        Riesgo-TPA              1,01          0         6          6
# 69  Riesgo propio-BR             23,17          5         0          5
# 70  Riesgo propio-BR              4,78          0         4          4
# 72  Riesgo propio-BR              1,89          0         0          0
#
#    Porc. disp No disp (HR) Porc. no disp  No respondidas
# 0       70,18     54:35:23         29,82               6
# 1       36,56    112:52:01         63,44               1
# 2       94,38     07:54:02          5,62               0
# 4       76,26     36:55:11         23,74               5
# 5       75,78     39:41:19         24,22              16
# 7       87,42     20:25:12         12,58               3
# 8        8,84     61:03:20         91,16               0
# 9       30,69     87:45:58         69,31               4
# 10      70,37     48:07:09         29,63               6
# 11      39,91     89:13:00         60,09               4
# 12      41,42     84:09:10         58,58               1
# 13      71,15     43:45:34         28,85               2
# 14       71,1     53:33:31          28,9               2
# 15       74,6     45:22:37          25,4               1
# 17      92,78     11:06:15          7,22               4
# 18      71,62     44:54:39         28,38               5
# 19       43,2    101:42:18          56,8               2
# 20      39,95     76:38:03         60,05               3
# 22      83,93     26:30:16         16,07              13
# 23      89,17     13:35:43         10,83               5
# 25      93,46     10:10:14          6,54              15
# 26      86,63     19:46:08         13,37               1
# 27      76,31     39:59:05         23,69               5
# 28      69,54     25:21:04         30,46               4
# 29      84,13     25:24:28         15,87               2
# 30      68,91     51:21:42         31,09              10
# 32      81,58     21:49:44         18,42               1
# 33      43,57     45:41:56         56,43               9
# 34      72,59     42:24:02         27,41               2
# 35      80,66     34:28:35         19,34               3
# 36      15,95     99:16:24         84,05               1
# 37      36,33     99:18:58         63,67               0
# 39      77,68     33:02:50         22,32               2
# 41       66,4     53:05:00          33,6               0
# 42       89,8     14:43:48          10,2               2
# 43      20,17     77:12:17         79,83               3
# 45      71,52     36:56:19         28,48               2
# 48      92,01     10:14:53          7,99               1
# 49      10,01     60:57:22         89,99               0
# 53      13,27    147:10:33         86,73               3
# 61      48,05     55:09:05         51,95               1
# 63      91,12     10:33:48          8,88               3
# 64       7,49     31:23:33         92,51               1
# 65      67,31     11:52:18         32,69               4
# 68       1,37     27:27:54         98,63               0
# 69      96,05     00:04:58          3,95               0
# 70      76,74     00:02:16         23,26               0
# 72       4,59     09:44:27         95,41               1

# %%
#Creo el excel para SUPs

datos4 = datos.loc[datos['Expertice'].isin(["Sup"])]
nombre_sup = f"{nombre_mes_actual} sup.csv"
datos4
# Out:
#                                  Operador Expertice   Turno            Equipo
# 50                    NESTOR DANIEL STARK       Sup   Tarde  Riesgo propio-BR  \
# 59  OROPEZA RODRIGUEZ ESTHEFANIA IVELISSA       Sup   Tarde  Riesgo propio-BR
# 60             GONZALEZ FERNANDO EZEQUIEL       Sup   Tarde  Riesgo propio-BR
# 62                    RENGEL PEDRO FELIPE       Sup   Tarde  Riesgo propio-BR
# 71   DOS SANTOS DOMINGUES CAMILA CAROLINA       Sup  Mañana  Riesgo propio-BR
#
#    Porc. en llamadas  Entrantes  Manuales  Salientes Porc. disp No disp (HR)
# 50              1,54          0        44         44      10,28    134:16:34  \
# 59              0,59          0        26         26       0,68    121:04:33
# 60              0,68          0        23         23      53,93     76:41:40
# 62               1,1          1        16         17       2,14    113:04:33
# 71              1,76          0         4          4       1,93     31:51:26
#
#    Porc. no disp  No respondidas
# 50         89,72               0
# 59         99,32               0
# 60         46,07               0
# 62         97,86               1
# 71         98,07               0

# %%
#Descargo la tabla general
datos.to_csv(nombre_archivo, index=False)

#Descargo la tabla SDF
datos2.to_csv(nombre_sdf, index=False)

#Descargo la tabla semana
datos3.to_csv(nombre_semana, index=False)

#Descargo la tabla sup
datos4.to_csv(nombre_sup, index=False)
